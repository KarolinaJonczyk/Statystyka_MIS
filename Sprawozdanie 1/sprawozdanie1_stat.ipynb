# %%
import matplotlib.pyplot as plt
labels = 'kierownik', 'sprzedawca\marketing', 'urzędnik', 'obsługa', 'wolny zawód', 'inne'
sizes = [55, 38, 97, 83, 105, 156]
explode = (0, 0, 0, 0, 0, 0)  
colors = ['darkorange','royalblue', 'crimson','grey', 'lightgreen', 'orchid' ]
fig1, ax1 = plt.subplots(figsize=(10,5))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal') 
title = plt.title('Zatrudnienie')
plt.tight_layout()
patches, texts = plt.pie(sizes, startangle=90, colors=colors)
plt.legend(patches, labels, loc="best")
plt.axis('equal')
plt.tight_layout()
plt.savefig('pie')

# %%
import pandas as pd

#create DataFrame
df = pd.DataFrame({'wykszt': ['edu1', 'edu2', 'edu3', 'suma osób'],
                   'points': [27, 275, 232, 534]})

#view DataFrame
df.sort_values(['points'], ascending = True)
# Out:
#       wykszt  points
# 0       edu1      27
# 2       edu3     232
# 1       edu2     275
# 3  suma osób     534

# %%
pensja = pd.DataFrame({'p':[2818.20, 5260.64,
4509.12,
10521.28,
4321.24,
2254.56,
3472.02,
6012.16,
5260.64,
4509.12,
2517.59,
3381.84,
3832.75,
4884.88,
3532.14,
6763.68,
2630.32,
3171.41,
8266.72,
5170.46,
2555.17,
6681.01,
3269.11,
3953.00,
2555.17,
6711.07,
3419.42,
3720.02,
4697.00,
15015.37,
3644.87,
5110.34,
3607.30,
6387.92,
7214.59,
2630.32,
2630.32,
7139.44,
4321.24,
3344.26,
4884.88,
3644.87,
5072.76,
6763.68,
5072.76,
3945.48,
4584.27,
7515.20,
5260.64,
6688.53,
7515.20,
9844.91,
6575.80,
2637.84,
7515.20,
2630.32,
2743.05,
3381.84,
4884.88,
2517.59,
3006.08,
4133.36,
7327.32,
10521.28,
7139.44,
2818.20,
10679.10,
8101.39,
2885.84,
2630.32,
4133.36,
5260.64,
5260.64,
3269.11,
3118.81,
2743.05,
2630.32,
4170.94,
5636.40,
4884.88,
3381.84,
9769.76,
6575.80,
5012.64,
3006.08,
5636.40,
14632.09,
6575.80,
8529.75,
8642.48,
5486.10,
16683.74,
15443.74,
4291.18,
2818.20,
7184.53,
7034.23,
2517.59,
3569.72,
3006.08,
6951.56,
8018.72,
5719.07,
7515.20,
5636.40,
2517.59,
9018.24,
4779.67,
6876.41,
3381.84,
3607.30,
4133.36,
7515.20,
3757.60,
8078.84,
8589.87,
3006.08,
9769.76,
9183.57,
4719.55,
7515.20,
3757.60,
12024.32,
9965.16,
7101.86,
6711.07,
4697.00,
5057.73,
5846.83,
2141.83,
2517.59,
15015.37,
6387.92,
11272.80,
6012.16,
4884.88,
7387.44,
9394.00,
7890.96,
9394.00,
11272.80,
4509.12,
9446.61,
4133.36,
5260.64,
3381.84,
4884.88,
9018.24,
3757.60,
4884.88,
2818.20,
3381.84,
4509.12,
4133.36,
9769.76,
3945.48,
4509.12,
5072.76,
6681.01,
5636.40,
3381.84,
8454.60,
10107.94,
3757.60,
4697.00,
6387.92,
3419.42,
8454.60,
5636.40,
4945.00,
11272.80,
5260.64,
2735.53,
7981.14,
8898.00,
9890.00,
3983.06,
3381.84,
751.52,
5869.37,
3381.84,
6763.68,
3193.96,
9394.00,
3855.30,
8349.39,
4809.73,
7515.20,
3569.72,
3006.08,
5260.64,
3757.60,
10303.34,
5636.40,
10438.61,
5636.40,
4621.85,
10107.94,
4697.00,
11821.41,
4058.21,
4133.36,
15406.16,
13527.36,
14564.46,
10521.28,
15030.40,
7515.20,
18772.97,
7515.20,
5012.64,
6012.16,
9018.24,
6681.01,
10258.25,
9521.76,
11693.65,
4697.00,
16909.20,
5636.40,
8860.42,
11558.38,
3757.60,
9506.73,
19757.46,
5170.46,
13647.60,
9018.24,
8454.60,
4411.42,
6387.92,
18772.97,
4509.12,
5861.86,
18772.97,
9018.24,
15331.01,
11986.74,
7665.50,
9394.00,
18772.97,
8454.60,
7139.44,
7041.74,
5260.64,
17472.84,
15030.40,
18772.97,
14278.88,
10483.70,
7515.20,
16909.20,
10017.76,
3907.90,
3915.42,
13527.36,
16683.74,
12963.72,
4291.18,
11272.80,
11272.80,
4396.39,
8432.05,
4291.18,
11866.50,
6012.16,
10153.04,
4697.00,
4697.00,
5260.64,
9018.24,
16683.74,
17157.20,
10521.28,
13647.60, 9018.24,8537.27]})

# %%
pd.reset_option('^display.', silent=True)

# %%
pensja.head()
# Out:
#           p
# 0   2818.20
# 1   5260.64
# 2   4509.12
# 3  10521.28
# 4   4321.24

# %%
sr = float(pensja.mean(axis=0))
print("Mediana zarobków wynosi: ", float(pensja.median(axis = 0)))
print("średnia pensja to: ", round(sr,2))
print("Maksymalna pensja to (wartość największa): ",float(pensja.max()), "\n",
      "Minimalna pensja to (wartość najmniejsza):", float(pensja.min()))
# Out:
# Mediana zarobków wynosi:  5846.83
# średnia pensja to:  6781.76
# Maksymalna pensja to (wartość największa):  33442.64
#  Minimalna pensja to (wartość najmniejsza): 751.52

# %%
pensja.sort_values(['p'], ascending = True)
# Out:
#             p
# 178    751.52
# 266   1315.16
# 336   1510.56
# 129   2141.83
# 5     2254.56
# ..        ...
# 413  18772.97
# 382  18788.00
# 345  19539.52
# 481  19757.46
# 352  33442.64
#
# [534 rows x 1 columns]

# %%
qu=pensja.quantile([0.25,0.75])
qu
#0.25 to pierwszy kwartyl
#0.75 to trzeci kwartyl
# Out:
#             p
# 0.25  3945.48
# 0.75  8454.60

# %%
print("Pierwszy kwartyl: ", qu.iloc[0,0])
print("Trzeci kwartyl: ", qu.iloc[1,0])
print("Rozstęp międzykwartylowy jest równy: ", round((qu.iloc[1,0] - qu.iloc[0,0]),2))
va=round(pensja.var(), 2)
import math
sqrt=round(float(math.sqrt(va)),2)
print("Wariancja wynosi: ",float(va), ", a odchylenie standardowe ma wartość: ", round(sqrt, 2))
# Out:
# Pierwszy kwartyl:  3945.48
# Trzeci kwartyl:  8454.6
# Rozstęp międzykwartylowy jest równy:  4509.12
# Wariancja wynosi:  14916079.17 , a odchylenie standardowe ma wartość:  3862.13

# %%
pensjaedu1 = pd.DataFrame({'wykształcenie podstawowe':[2818.20,
5260.64,
4509.12,
10521.28,
4321.24,
2254.56,
3472.02,
6012.16,
5260.64,
4509.12,
2517.59,
3381.84,
3832.75,
4884.88,
3532.14,
6763.68,
2630.32,
3171.41,
8266.72,
5170.46,
2555.17,
6681.01,
3269.11,
3953.00,
12963.72,
4291.1792,
11272.8,
11272.8,
4396.392,
8432.0544,
4291.1792,
11866.5008,
6012.16,
10153.0352,
4697,
4697,
5260.64,
9018.24,
16683.744,
17157.2016,
10521.28,
13647.6032,
9018.24,
8537.2672]})

# %%
pensjaedu1.sort_values(['wykształcenie podstawowe'], ascending = True) 
print(pensjaedu1.to_string(max_rows=6))
# Out:
#     wykształcenie podstawowe
# 0                    2818.20
# 1                    5260.64
# 2                    4509.12
# ..                       ...
# 24                   2555.17
# 25                   6711.07
# 26                   3419.42

# %%
pensjaedu2.sort_values(['wykształcenie średnie'], ascending = True)
print(pensjaedu2.to_string(max_rows=6))
# Out:
#      wykształcenie średnie
# 0                3720.0240
# 1                4697.0000
# 2               15015.3696
# ..                     ...
# 272             12024.3200
# 273              4584.2720
# 274             14940.2176

# %%
pensjaedu3.sort_values(['wykształcenie wyższe'], ascending = True)
print(pensjaedu3.to_string(max_rows=6))
# Out:
#      wykształcenie wyższe
# 0               9822.3664
# 1               3231.5360
# 2               3006.0800
# ..                    ...
# 229            13647.6032
# 230             9018.2400
# 231             8537.2672

# %%
print("Maksymalna pensja to dla 1 poziomu to: ",float(pensjaedu1.max()), "dla 2 poziomu to: ", float(round(pensjaedu2.max(),2)),
      "a dla 3: ", float(pensjaedu3.max()), "\n","Minimalna pensja to: ", float(pensjaedu1.min()),
      "dla 2 poziomu to: ", float(pensjaedu2.min()), "a dla 3: ", float(round(pensjaedu3.min(), 2)))
print("Mediana zarobków dla 1 poziomu to: ",float(pensjaedu1.median(axis = 0)), "dla 2 poziomu to: ", 
      float(round(pensjaedu2.median(axis = 0),2)), "a dla 3: ", float(pensjaedu3.median(axis = 0)) )
print("średnia pensja dla 1 poziomu to: ",float(round(pensjaedu1.mean(axis=0),2)), "dla 2 poziomu to: ", 
      float(round(pensjaedu2.mean(axis=0),2)),"a dla 3: ", float(round(pensjaedu3.mean(axis=0),2)))
# Out:
# Maksymalna pensja to dla 1 poziomu to:  10521.28 dla 2 poziomu to:  16683.74 a dla 3:  33442.64
#  Minimalna pensja to:  2254.56 dla 2 poziomu to:  751.52 a dla 3:  1510.56
# Mediana zarobków dla 1 poziomu to:  3953.0 dla 2 poziomu to:  5110.34 a dla 3:  7515.2
# średnia pensja dla 1 poziomu to:  4527.21 dla 2 poziomu to:  5726.69 a dla 3:  8294.77

# %%
qu1=pensjaedu1.quantile([0.25,0.75])
qu2=pensjaedu2.quantile([0.25,0.75])
qu3=pensjaedu3.quantile([0.25,0.75])
qu123 = pd.DataFrame({'q1':[qu1], 'q2':[qu2], 'q3': qu3})
#0.25 to pierwszy kwartyl
#0.75 to trzeci kwartyl

# %%
qu1
# Out:
#       wykształcenie podstawowe
# 0.25                   3220.26
# 0.75                   5260.64

# %%
print("Pierwszy kwartyl: ", qu1.iloc[0,0])
print("Trzeci kwartyl: ", qu1.iloc[1,0])
# Out:
# Pierwszy kwartyl:  3220.26
# Trzeci kwartyl:  5260.64

# %%
qu2
# Out:
#         wykształcenie średnie
# 25.00%             362608.40%
# 75.00%             716198.56%

# %%
print("Pierwszy kwartyl: ", qu2.iloc[0,0])
print("Trzeci kwartyl: ", qu2.iloc[1,0])
# Out:
# Pierwszy kwartyl:  3626.084
# Trzeci kwartyl:  7161.9856

# %%
qu3
# Out:
#       wykształcenie wyższe
# 0.25             4697.0000
# 0.75            10449.8856

# %%
print("Pierwszy kwartyl: ", qu3.iloc[0,0])
print("Trzeci kwartyl: ", qu3.iloc[1,0])
# Out:
# Pierwszy kwartyl:  4697.0
# Trzeci kwartyl:  10449.885600000001

# %%
print("Rozstęp międzykwartylowy dla 1 poziomu jest równy: ", (qu1.iloc[1,0] - qu1.iloc[0,0]),
     "dla 2 poziomu to: ", round((qu2.iloc[1,0] - qu2.iloc[0,0]), 2), "a dla 3: ", round((qu3.iloc[1,0] - qu3.iloc[0,0]),2))
va1=round(pensjaedu1.var(), 2)
va2=round(pensjaedu2.var(), 2)
va3=round(pensjaedu3.var(), 2)

print("Wariancja dla 1 poziomu edukacji wynosi: ", float(va1), "dla 2 poziomu: ", float(va2), "i dla 3 poziomu: ", float(va3),
      "\n", "Odchylenie standardowe dla 1 poziomu ma wartość: ", round(math.sqrt(va1), 2), "dla 2 poziomu to: ",
      round(math.sqrt(va2), 2),
     "i dla 3: ", round(math.sqrt(va3),2))
# Out:
# Rozstęp międzykwartylowy dla 1 poziomu jest równy:  2040.38 dla 2 poziomu to:  3535.9 a dla 3:  5752.89
# Wariancja dla 1 poziomu edukacji wynosi:  3867860.11 dla 2 poziomu:  7654232.04 i dla 3 poziomu:  20683932.44
#  Odchylenie standardowe dla 1 poziomu ma wartość:  1966.69 dla 2 poziomu to:  2766.63 i dla 3:  4547.96

# %%
import pandas as pd
import numpy as np
data=pd.DataFrame(index=['wykształcenie podstawowe','wykształcenie średnie','wykształcenie wyższe'])
data['pensja minimalna']=np.array([2254.56,751.52,1510.56])
data['pensja maksymalna']=np.array([10521.28,16683.74,33442.64])
data['mediana']=np.array([3953.00,5110.34,7515.20])
data['średnia']=np.array([4527.21,5726.69,8294.77])
data['kwantyl 1']=np.array([3220.26,3626.08,4697.00])
data['kwantyl 3']=np.array([5260.64,7161.98,10449.88])
data['rozstęp międzykwantylowy']=np.array([2040.38,3535.90,5752.89])
data['wariancja']=np.array([3867860.11,7654232.04,20683932.44])
data['odchylenie standardowe']=np.array([1966.69,2766.63,4547.96])
data.head()
# Out:
#                           pensja minimalna  pensja maksymalna  mediana  \
# wykształcenie podstawowe           2254.56           10521.28  3953.00
# wykształcenie średnie               751.52           16683.74  5110.34
# wykształcenie wyższe               1510.56           33442.64  7515.20
#
#                           średnia  kwantyl 1  kwantyl 3  \
# wykształcenie podstawowe  4527.21    3220.26    5260.64
# wykształcenie średnie     5726.69    3626.08    7161.98
# wykształcenie wyższe      8294.77    4697.00   10449.88
#
#                           rozstęp międzykwantylowy    wariancja  \
# wykształcenie podstawowe                   2040.38   3867860.11
# wykształcenie średnie                      3535.90   7654232.04
# wykształcenie wyższe                       5752.89  20683932.44
#
#                           odchylenie standardowe
# wykształcenie podstawowe                 1966.69
# wykształcenie średnie                    2766.63
# ...

# %%
import pandas as pd
import numpy as np
pd.reset_option('^display.', silent=True)


data=pd.DataFrame(index=['pensja minimalna','pensja maksymalna','mediana','średnia','kwantyl 1','kwantyl 3',
                         'rozstęp międzykwantylowy','wariancja','odchylenie standardowe'])
data['wykształcenie podstawowe']=np.array([2254.56, 10521.28,3953.00,  4527.21,3220.26,5260.64,2040.38,3867860.11,1966.69])
data['wykształcenie średnie']=np.array([751.52,16683.74,5110.34,5726.69,3626.08,7161.98,3535.90,7654232.04,2766.63])
data['wykształcenie wyższe']=np.array([1510.56,33442.64,7515.20,8294.77,4697.00,10449.88,5752.89,20683932.44,4547.96])
data.head(10)
# Out:
#                           wykształcenie podstawowe  wykształcenie średnie  \
# pensja minimalna                           2254.56                 751.52
# pensja maksymalna                         10521.28               16683.74
# mediana                                    3953.00                5110.34
# średnia                                    4527.21                5726.69
# kwantyl 1                                  3220.26                3626.08
# kwantyl 3                                  5260.64                7161.98
# rozstęp międzykwantylowy                   2040.38                3535.90
# wariancja                               3867860.11             7654232.04
# odchylenie standardowe                     1966.69                2766.63
#
#                           wykształcenie wyższe
# pensja minimalna                       1510.56
# pensja maksymalna                     33442.64
# mediana                                7515.20
# ...

# %%
data1 = [2818.20,
5260.64,
4509.12,
10521.28,
4321.24,
2254.56,
3472.02,
6012.16,
5260.64,
4509.12,
2517.59,
3381.84,
3832.75,
4884.88,
3532.14,
6763.68,
2630.32,
3171.41,
8266.72,
5170.46,
2555.17,
6681.01,
3269.11,
3953.00,
2555.17,
6711.07,
3419.42]
data2 = [3720.024,4697,
15015.3696,
3644.872,
5110.336,
3607.296,
6387.92,
7214.592,
2630.32,
2630.32,
7139.44,
4321.24,
3344.264,
4884.88,
3644.872,
5072.76,
6763.68,
5072.76,
3945.48,
4584.272,
7515.2,
5260.64,
6688.528,
7515.2,
9844.912,
6575.8,
2637.8352,
7515.2,
2630.32,
2743.048,
3381.84,
4884.88,
2517.592,
3006.08,
4133.36,
7327.32,
10521.28,
7139.44,
2818.2,
10679.0992,
8101.3856,
2885.8368,
2630.32,
4133.36,
5260.64,
5260.64,
3269.112,
3118.808,
2743.048,
2630.32,
4170.936,
5636.4,
4884.88,
3381.84,
9769.76,
6575.8,
5012.6384,
3006.08,
5636.4,
14632.0944,
6575.8,
8529.752,
8642.48,
5486.096,
16683.744,
15443.736,
4291.1792,
2818.2,
7184.5312,
7034.2272,
2517.592,
3569.72,
3006.08,
6951.56,
8018.7184,
5719.0672,
7515.2,
5636.4,
2517.592,
9018.24,
4779.6672,
6876.408,
3381.84,
3607.296,
4133.36,
7515.2,
3757.6,
8078.84,
8589.8736,
3006.08,
9769.76,
9183.5744,
4719.5456,
7515.2,
3757.6,
12024.32,
9965.1552,
7101.864,
6711.0736,
4697,
5057.7296,
5846.8256,
2141.832,
2517.592,
15015.3696,
6387.92,
11272.8,
6012.16,
4884.88,
7387.4416,
9394,
7890.96,
9394,
11272.8,
4509.12,
9446.6064,
4133.36,
5260.64,
3381.84,
4884.88,
9018.24,
3757.6,
4884.88,
12963.72,
2818.2,
9394,
4509.12,
7973.6272,
7725.6256,
7409.9872,
8454.6,
5764.1584,
9394,
9980.1856,
11272.8,
8266.72,
2818.2,
3757.6,
18772.9696,
2517.592,
10107.944,
8454.6,
10919.5856,
4509.12,
9920.064,
16909.2,
11272.8,
7515.2,
7041.7424,
4358.816,
6763.68,
7981.1424,
11272.8,
2517.592,
4246.088,
8642.48,
7515.2,
6763.68,
4133.36,
3757.6,
3945.48,
2517.592,
4697,
5921.9776,
8800.2992,
3381.84,
3006.08,
6763.68,
4336.2704,
9055.816,
6944.0448,
7515.2,
13151.6,
5846.8256,
7515.2,
7951.0816,
10438.6128,
5636.4,
4621.848,
10107.944,
4697,
11821.4096,
4058.208,
4133.36,
15406.16,
13527.36,
14564.4576,
10521.28,
15030.4,
7515.2,
18772.9696,
7515.2,
5012.6384,
6012.16,
9018.24,
6681.0128,
10258.248,
9521.7584,
11693.6512,
4697,
16909.2,
5636.4,
8860.4208,
11558.3776,
3757.6,
9506.728,
19757.4608,
5170.4576,
13647.6032,
9018.24,
8454.6,
4411.4224,
6387.92,
18772.9696,
4509.12,
5861.856,
18772.9696,
9018.24,
15331.008,
11986.744,
7665.504,
9394,
18772.9696,
8454.6,
7139.44,
7041.7424,
5260.64,
17472.84,
15030.4,
18772.9696,
14278.88,
10483.704,
7515.2,
16909.2,
10017.7616,
3907.904,
3915.4192,
13527.36,
16683.744,
12963.72,
4291.1792,
11272.8,
11272.8,
4396.392,
8432.0544,
4291.1792,
11866.5008,
6012.16,
10153.0352,
4697,
4697,
5260.64,
9018.24,
16683.744,
17157.2016,
10521.28,
13647.6032,
9018.24,
8537.2672]
data = [data1,data2, data3]
colors = ['lightblue','lightcoral','darkgoldenrod']
fig, ax = plt.subplots()
box_dict = ax.boxplot(data, patch_artist=True,  showmeans=True)
for item in ['boxes', 'fliers', 'medians', 'means']:
    for sub_item,color in zip(box_dict[item], colors):
        plt.setp(sub_item, color=color)
# whiskers and caps have to be treated separately since there are two of each for each plot
for item in ['whiskers', 'caps']:
    for sub_items,color in zip(zip(box_dict[item][::2],box_dict[item][1::2]),colors):
        plt.setp(sub_items, color=color)
plt.savefig('boxes')

# %%
from scipy import interpolate
import matplotlib.pyplot as plt

#x=np.linspace(0,len(pensja),10000)
#y=CubicSpline(x, pensja)


n, x,_ = plt.hist(pensja, edgecolor="black", color='paleturquoise')
HELP=[(x[i]+x[i-1])/2 for i in range (1,len(x))]
HELP=np.insert(HELP,0,0,axis=0)
n=np.insert(n,0,0,axis=0)
#y=CubicSpline(HELP,n)
Z=interpolate.interp1d(HELP,n,kind='cubic')
X=np.linspace(0,np.max(HELP),1000)
y=Z(X)
plt.plot(X,y,'orangered')
plt.title("Histogram podstawowy")
plt.savefig('podst')

# %%
#
# Values of random variable
#
x = np.linspace(-10, 10, 100)
#
plt.figure(figsize=(7.5,7.5))
#
# Normal distribution with mean 0 and std as 1
#
plt.plot(x, stats.norm(0, 1).pdf(x))
#
# Normal distribution with mean 1 and std as 0.75
#
plt.plot(x, stats.norm(1, 0.75).pdf(x))
#
# Normal distribution with mean 2 and std as 1.5
#
plt.plot(x, stats.norm(2, 1.5).pdf(x))
plt.xlim(-10, 10)
plt.title('Normal Distribution', fontsize='15')
plt.xlabel('Values of Random Variable X', fontsize='15')
plt.ylabel('Probability', fontsize='15')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-577-1311ef75e45e> in <module>
#       8 # Normal distribution with mean 0 and std as 1
#       9 #
# ---> 10 plt.plot(x, stats.norm(0, 1).pdf(x))
#      11 #
#      12 # Normal distribution with mean 1 and std as 0.75
#
# AttributeError: module 'astropy.stats' has no attribute 'norm'

# %%
IQR = 4509.12
n = 534
k=1/3
h=2*IQR*(n**(-k))

xmax = 33442.64 
x1= 751.52
xmax-x1
numclass = math.ceil((xmax-x1)/h)
h, numclass
print("h wynosi: ", h, "\n","liczba klas wyznaczona za pomocą reguły Freedmana-Diaconisa to: ", numclass)
# Out:
# h wynosi:  1111.5816526875694
#  liczba klas wyznaczona za pomocą reguły Freedmana-Diaconisa to:  30

# %%
def zerowanie(y):
    return y if y>=0 else 0
zerowanie=np.vectorize(zerowanie)

plt.title("Histogram z regułą Freedmana-Diaconisa:")
n,x,_=plt.hist(pensja, edgecolor="black", bins=numclass, color = 'tomato') #bins to liczba klas

HELP=[(x[i]+x[i-1])/2 for i in range (1,len(x))]
HELP=np.insert(HELP,0,0,axis=0)
n=np.insert(n,0,0,axis=0)
Z=interpolate.interp1d(HELP,n,kind='cubic')
X=np.linspace(0,np.max(HELP),1000)
y=Z(X)
y=zerowanie(y)
plt.plot(X,y,'black')
plt.savefig('reg')

# %%
import numpy as np
from astropy import stats

# %%
osoby=pd.DataFrame(index=['rasa biała','rasa ameryka centralna/płd','rasa inna','razem',])
osoby['wykształcenie podstawowe']=np.array([14, 8, 5, 27])
osoby['wykształcenie średnie']=np.array([230, 8, 37, 275])
osoby['wykształcenie wyższe']=np.array([196, 11, 25, 232])
osoby['razem']=np.array([440, 27, 67, 534])
osoby.head(10)
# Out:
#                             wykształcenie podstawowe  wykształcenie średnie  \
# rasa biała                                        14                    230
# rasa ameryka centralna/płd                         8                      8
# rasa inna                                          5                     37
# razem                                             27                    275
#
#                             wykształcenie wyższe  razem
# rasa biała                                   196    440
# rasa ameryka centralna/płd                    11     27
# rasa inna                                     25     67
# razem                                        232    534

# %%
pd.options.display.float_format = '{:.2%}'.format
procent=pd.DataFrame(index=['rasa biała','rasa ameryka centralna/płd','rasa inna','razem',])
procent['wykształcenie podstawowe']=np.array([0.0262, 0.015, 0.0094, 0.0506])
procent['wykształcenie średnie']=np.array([0.4307, 0.0150, 0.0693, 0.5150])
procent['wykształcenie wyższe']=np.array([0.3670, 0.0206, 0.0468, 0.4345])
procent['razem']=np.array([0.8240, 0.0506, 0.1255, 1.0])
procent.head(10)
# Out:
#                             wykształcenie podstawowe  wykształcenie średnie  \
# rasa biała                                     2.62%                 43.07%
# rasa ameryka centralna/płd                     1.50%                  1.50%
# rasa inna                                      0.94%                  6.93%
# razem                                          5.06%                 51.50%
#
#                             wykształcenie wyższe   razem
# rasa biała                                36.70%  82.40%
# rasa ameryka centralna/płd                 2.06%   5.06%
# rasa inna                                  4.68%  12.55%
# razem                                     43.45% 100.00%
