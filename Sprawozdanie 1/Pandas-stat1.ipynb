# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
data=pd.read_excel('lab1.xlsx',index_col=0, parse_dates=True)
display(data)
# Out:
#      miejsce  plec  staz  zwiazek  zarobki  wiek  rasa  praca  sektor  stan
# edu
# 2          0     0    16        0     3.75    24     2      4       0     0
# 3          1     0    55        0     7.00    64     2      6       1     1
# 4          0     0    54        0     6.00    64     3      4       0     1
# 5          1     0    44        0    14.00    55     3      6       2     1
# 6          1     0    45        0     5.75    57     3      6       1     1
# ..       ...   ...   ...      ...      ...   ...   ...    ...     ...   ...
# 18         0     1    37        0    22.83    61     3      5       1     0
# 18         0     1    31        1    14.00    55     3      5       0     0
# 18         0     0     7        0    18.16    31     3      5       0     1
# 18         0     0    23        1    12.00    47     3      5       0     1
# 18         0     0     5        0    11.36    29     3      5       0     0
#
# [534 rows x 10 columns]

# %%
def zwykle_bar(nazwa):
    D=data[nazwa].squeeze().value_counts().to_dict()
    fig,ax=plt.subplots(1,1,figsize=(16,6))
    ax.bar(D.keys(),D.values())
def laczone_pie(nazwa,rozdzielnik,a):
    D=data[nazwa].to_numpy(dtype=np.float64)
    fig,ax=plt.subplots(figsize=(16,16),facecolor='white')
    ax.pie(D,startangle=69,autopct='%1.1f%%',wedgeprops = {'linewidth': 3},shadow=False,textprops={'fontsize': 14,'weight': 'light'})
    #ax.pie(list(D.values()),startangle=69,autopct='%1.1f%%',wedgeprops = {'linewidth': 3},shadow=True,explode=explode)
    #ax.legend(D.keys())
    ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
    ax.set_title(t[a],size=20,weight='bold')
    fig.savefig(str(a))
#    plt.close()
def bar(nazwa,rozdzielnik,a):
    D=data[nazwa].squeeze().str.split(',').explode().value_counts().to_dict()
    fig,ax=plt.subplots(figsize=(16,16),facecolor='white')
    ax.bar(D.keys(),D.values())
    ax.legend(list(D.keys()))
    ax.set_yticks(list(D.values()))
    ax.set_title(str(nazwa),size=20,weight='bold')
    #fig.savefig(str(a))
    #plt.close()

# %%
laczone_pie('praca',',',1)

# %%
laczone_pie('miejsce',',',1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-3cc997418ae0> in <module>
# ----> 1 laczone_pie('miejsce',',',1)
#
# <ipython-input-16-4e7bcd311b1b> in laczone_pie(nazwa, rozdzielnik, a)
#       4     ax.bar(D.keys(),D.values())
#       5 def laczone_pie(nazwa,rozdzielnik,a):
# ----> 6     D=data[nazwa].squeeze().str.split(',').explode().value_counts().to_dict()
#       7     explode=np.ones(len(D.keys()))*0.05
#       8     fig,ax=plt.subplots(figsize=(16,16),facecolor='white')
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5459             or name in self._accessors
#    5460         ):
# -> 5461             return object.__getattribute__(self, name)
#    5462         else:
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ...
