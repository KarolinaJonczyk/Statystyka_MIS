.127079215,3.397303362,3.325330056,3.332517916,3.469757439,3.041745648,3.296058116,3.391155552,3.462771305,3.230992003,3.319458653,3.327265773,3.375102995,3.405319098,3.183197914,3.004241431,3.40618013,3.256245837,3.436278655,3.468526517,3.360617476,3.079483934,3.442298912,3.126266317,3.271685946,3.061761009,3.499070715,3.364985286,3.014772063,3.427444106,3.454982853,3.257624764,3.038591066,3.124199142,3.010824535,3.089595189,3.248541323,3.021496485,3.42093232,3.110699732,3.386928695,3.284936685,3.037461808,3.212566503,3.071410985,3.16272327,3.194033483,3.406403054,3.010382445,3.209175446,3.323459957,3.40876813,3.261289657,3.313251364,3.042192442,3.345040482,3.176766656,3.245890718,3.062657464,3.229399064,3.441789325,3.109842525,3.471986767,3.347209375,3.086917725,3.30005108,3.316006967,3.431419718,3.379164869,3.385502237,3.007719988,3.102590954,3.025307913,3.238266926,3.33303641,3.265303283,3.408143138,3.360667214,3.030105981,3.342595367,3.217851291,3.249580634,3.227759335,3.307246772,3.402435531,3.30961269,3.278958918,3.339192807,3.172224345,3.132733069,3.345061452,3.236090608,3.139529818,3.10987305,3.10669179,3.258114158,3.192147744,3.288936966,3.42242617,3.033146379,3.331135213,3.097099892]})

# %% [markdown]
# $X1$

# %%
qu1=X1.quantile([0.25,0.75])
qu1
# Out:
#             x1
# 0.25 -0.516454
# 0.75  0.751152

# %%
round(qu1.iloc[1,0] - qu1.iloc[0,0],6)
# Out:
# 1.267606

# %%
round(float(X1.median(axis = 0)),6)
# Out:
# 0.136173

# %%
on=float(X1.max())
du=float(X2.max())
ta = float(X3.max())
vi = float(X4.max())
fu = float(X5.max())
on,du,ta,vi,fu
# Out:
# (2.562231779, 2.765292409, 6.149898348, 0.828053648, 3.499070715)

# %%
o=float(X1.min())
d=float(X2.min())
t = float(X3.min())
v = float(X4.min())
f = float(X5.min())
o,d,t,v,f
# Out:
# (-2.597755919, 0.001645128, 0.228095753, 0.065548043, 3.002806192)

# %%
q = round(float(X1.mean(axis=0)),6)
w = round(float(X2.mean(axis=0)),6)
e = round(float(X3.mean(axis=0)),6)
r = round(float(X4.mean(axis=0)),6)
t = round(float(X5.mean(axis=0)),6)
q,w,e,r,t
# Out:
# (0.084105, 0.458492, 2.050448, 0.43681, 3.254505)

# %%
va1=float(round(X1.var(), 6))
va2=float(round(X2.var(), 6))
va3=float(round(X3.var(), 6))
va4=float(round(X4.var(), 6))
va5=float(round(X5.var(), 6))
va1,va2,va3,va4,va5
# Out:
# (0.917076, 0.175092, 1.022843, 0.025619, 0.019664)

# %%
o1=round(float(math.sqrt(va1)),6)
o2=round(float(math.sqrt(va2)),6)
o3=round(float(math.sqrt(va3)),6)
o4=round(float(math.sqrt(va4)),6)
o5=round(float(math.sqrt(va5)),6)
o1,o2,o3,o4,o5
# Out:
# (0.959166, 0.424264, 1.00995, 0.173205, 0.141421)

# %% [markdown]
# $X2$

# %%
qu2=X2.quantile([0.25,0.75])
qu2
# Out:
#             x2
# 0.25  0.125895
# 0.75  0.713308

# %%
round(qu2.iloc[1,0] - qu2.iloc[0,0], 6)
# Out:
# 0.587413

# %%
round(float(X2.median(axis = 0)),6)
# Out:
# 0.35977

# %% [markdown]
# $X3$

# %%
qu3=X3.quantile([0.25,0.75])
qu3
# Out:
#             x3
# 0.25  1.284800
# 0.75  2.647976

# %%
round(qu3.iloc[1,0] - qu3.iloc[0,0],6)
# Out:
# 1.363176

# %%
round(float(X3.median(axis = 0)),6)
# Out:
# 1.842994

# %% [markdown]
# $X4$

# %%
qu4=X4.quantile([0.25,0.75])
qu4
# Out:
#             x4
# 0.25  0.322431
# 0.75  0.535963

# %%
round(qu4.iloc[1,0] - qu4.iloc[0,0],6)
# Out:
# 0.213533

# %%
round(float(X4.median(axis = 0)),6)
# Out:
# 0.426759

# %% [markdown]
# $X5$

# %%
qu5=X5.quantile([0.25,0.75])
qu5
# Out:
#             x5
# 0.25  3.130252
# 0.75  3.363135

# %%
round(qu5.iloc[1,0] - qu5.iloc[0,0],6)
# Out:
# 0.232882

# %%
round(float(X5.median(axis = 0)),6)
# Out:
# 3.266009

# %%
data=pd.DataFrame(index=['X1','X2','X3', 'X4', 'X5'])
data['wartość minimalna']=np.array([o,d,t,v,f])
data['wartość maksymalna']=np.array([on,du,ta,vi,fu])
data['mediana']=np.array([0.136173,0.35977,1.842994,0.426759,3.266009])
data['średnia']=np.array([q,w,e,r,t])
data['kwantyl 1']=np.array([-0.516454,0.125895,1.284800,0.322431,3.130252])
data['kwantyl 3']=np.array([0.751152,0.713308,2.647976,0.535963,3.363135])
data['rozstęp międzykwantylowy']=np.array([1.267606, 0.587413,1.363176, 0.213533,0.232882])
data['wariancja']=np.array([va1,va2,va3,va4,va5])
data['odchylenie standardowe']=np.array([o1,o2,o3,o4,o5])
data.head()
# Out:
#     wartość minimalna  wartość maksymalna   mediana   średnia  kwantyl 1  \
# X1          -2.597756            2.562232  0.136173  0.084105  -0.516454
# X2           0.001645            2.765292  0.359770  0.458492   0.125895
# X3           3.254505            6.149898  1.842994  2.050448   1.284800
# X4           0.065548            0.828054  0.426759  0.436810   0.322431
# X5           3.002806            3.499071  3.266009  3.254505   3.130252
#
#     kwantyl 3  rozstęp międzykwantylowy  wariancja  odchylenie standardowe
# X1   0.751152                  1.267606   0.917076                0.959166
# X2   0.713308                  0.587413   0.175092                0.424264
# X3   2.647976                  1.363176   1.022843                1.009950
# X4   0.535963                  0.213533   0.025619                0.173205
# X5   3.363135                  0.232882   0.019664                0.141421

# %%
X1.head(n=200)
# Out:
#            x1
# 0   -0.515335
# 1    0.552426
# 2   -0.017972
# 3    0.112978
# 4   -0.102186
# ..        ...
# 195 -1.501342
# 196 -1.520842
# 197  0.326423
# 198 -0.003839
# 199 -0.003207
#
# [200 rows x 1 columns]

# %%
X2.head(n=200)
# Out:
#            x2
# 0    0.040165
# 1    0.348660
# 2    0.694392
# 3    0.568921
# 4    0.011864
# ..        ...
# 195  0.384908
# 196  0.090058
# 197  0.590869
# 198  0.065240
# 199  0.907793
#
# [200 rows x 1 columns]

# %%
X3.head(n=200)
# Out:
#            x3
# 0    2.510694
# 1    1.311645
# 2    0.445459
# 3    2.541082
# 4    1.352404
# ..        ...
# 195  1.116127
# 196  1.077874
# 197  2.007137
# 198  0.817075
# 199  2.687964
#
# [200 rows x 1 columns]

# %%
X4.head(n=200)
# Out:
#            x4
# 0    0.361159
# 1    0.753115
# 2    0.491309
# 3    0.263286
# 4    0.719480
# ..        ...
# 195  0.411006
# 196  0.368515
# 197  0.565151
# 198  0.564635
# 199  0.518283
#
# [200 rows x 1 columns]

# %%
X5.head(n=200)
# Out:
#            x5
# 0    3.285627
# 1    3.353182
# 2    3.154962
# 3    3.359753
# 4    3.183489
# ..        ...
# 195  3.288937
# 196  3.422426
# 197  3.033146
# 198  3.331135
# 199  3.097100
#
# [200 rows x 1 columns]

# %% [markdown]
# Przykłady rozkładów dla prób $X_1 - X_5$

# %%
normalVar = pd.DataFrame(np.random.normal(0,10,70))
normalVar.columns = ['value']
normalVar.head()
sns.distplot(normalVar, color='black')
plt.title("Przykładowy rozkład normalny")
plt.savefig('normalexample')
# Out:
# /Users/karolinajonczyk/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from scipy.stats import gamma
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 1)
a = 1.99
mean, var, skew, kurt = gamma.stats(a, moments='mvsk')
x = np.linspace(gamma.ppf(0.01, a), gamma.ppf(0.99, a), 100)
#ax.plot(x, gamma.pdf(x, a),'r-', lw=5, alpha=0.6, label='gamma pdf')
rv = gamma(a)
ax.plot(x, rv.pdf(x), 'k-', lw=2, label='gamma')
vals = gamma.ppf([0.001, 0.5, 0.999], a)
np.allclose([0.001, 0.5, 0.999], gamma.cdf(vals, a))
r = gamma.rvs(a, size=1000)
ax.hist(r, density=True, alpha=0.2, color='black')
ax.legend(loc='best', frameon=False)
plt.title("Przykładowy rozkład gamma")
plt.savefig('gammaexample')

# %%
sns.set_style("whitegrid", {'axes.grid' : False})
sns.distplot(random.uniform(size=100), hist=True, color='black')  
plt.title("Przykładowy rozkład jednostajny")
plt.savefig("uniformexample")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/0x/h28nyhtx0xzdjlz02d7g9nmr0000gn/T/ipykernel_2572/3678558902.py in <module>
#       1 sns.set_style("whitegrid", {'axes.grid' : False})
# ----> 2 sns.distplot(random.uniform(size=100), hist=True, color='black')
#       3 plt.title("Przykładowy rozkład jednostajny")
#       4 plt.savefig("uniformexample")
#
# NameError: name 'random' is not defined

# %%
#n, x,_ = plt.hist(X1, edgecolor="black", color='paleturquoise')
HELP=[(x[i]+x[i-1])/2 for i in range (1,len(x))]
Z=interpolate.interp1d(HELP,n,kind='cubic')
X=np.linspace(np.min(HELP),np.max(HELP),1000)
y=Z(X)
fig,ax=plt.subplots(figsize=(6,4))
ax.hist(X1, edgecolor="black", color='paleturquoise')
ax.plot(X,y,'orangered')
plt.title("Histogram $x_1$")
# Out:
# Text(0.5, 1.0, 'Histogram $x_1$')

# %%
n, x,_ = plt.hist(X2, edgecolor="black", color='paleturquoise')
HELP=[(x[i]+x[i-1])/2 for i in range (1,len(x))]
HELP=np.insert(HELP,0,0,axis=0)
n=np.insert(n,0,0,axis=0)
#y=CubicSpline(HELP,n)
Z=interpolate.interp1d(HELP,n,kind='cubic')
X=np.linspace(np.min(HELP),np.max(HELP),1000)
y=Z(X)
plt.plot(X,y,'orangered')
plt.title("Histogram $x_2$")
plt.savefig('hist2')

# %%
n, x,_ = plt.hist(X3, edgecolor="black", color='paleturquoise')
HELP=[(x[i]+x[i-1])/2 for i in range (1,len(x))]
HELP=np.insert(HELP,0,0,axis=0)
n=np.insert(n,0,0,axis=0)
#y=CubicSpline(HELP,n)
Z=interpolate.interp1d(HELP,n,kind='cubic')
X=np.linspace(np.min(HELP),np.max(HELP),1000)
y=Z(X)
plt.plot(X,y,'orangered')
plt.title("Histogram $x_3$")
plt.savefig('hist3')

# %%
n, x,_ = plt.hist(X4, edgecolor="black", color='paleturquoise')
HELP=[(x[i]+x[i-1])/2 for i in range (1,len(x))]
HELP=np.insert(HELP,0,0,axis=0)
n=np.insert(n,0,0,axis=0)
#y=CubicSpline(HELP,n)
Z=interpolate.interp1d(HELP,n,kind='cubic')
X=np.linspace(np.min(HELP),np.max(HELP),1000)
y=Z(X)
plt.plot(X,y,'orangered')
plt.title("Histogram $x_4$")
plt.savefig('hist4')

# %%
n, x,_ = plt.hist(X5, edgecolor="black", color='paleturquoise')
HELP=[(x[i]+x[i-1])/2 for i in range (1,len(x))]
HELP=np.insert(HELP,0,0,axis=0)
n=np.insert(n,0,0,axis=0)
#y=CubicSpline(HELP,n)
Z=interpolate.interp1d(HELP,n,kind='cubic')
X=np.linspace(3,np.max(HELP),1000)
y=Z(X)
plt.plot(X,y,'orangered')
plt.title("Histogram $x_5$")
plt.savefig('hist5')

# %% [markdown]
# Podaj wartości estymatorów parametrów, charakteryzujących każdą z tych gęstości.

# %%
#wyżej

# %% [markdown]
# # Zadanie 2

# %% [markdown]
# Próba rozmiaru $n=100$ dla rozkładu normalnego $N(1,2^2)$. \
# $N(1,4)=N(1,2^2)=N(\mu, \sigma)$

# %%
from scipy.stats import beta
import matplotlib.pyplot as plt
import numpy as np
a = 1
b = 1
x = np.arange (0,1, 1)
y = beta.pdf(x,a,b, scale=100)
fig,ax=plt.subplots(figsize=(6,4))
ax.hist(random.beta(1,1, size=100), edgecolor="black", color='paleturquoise')
ax.plot(x,y,'orangered')
plt.title("Rozkład beta $B(1,1)$ dla $n=100$ prób")
# Out:
# Text(0.5, 1.0, 'Rozkład beta $B(1,1)$ dla $n=100$ prób')

# %%
k=plt.hist(random.beta(1,1, 100),edgecolor="black", color='paleturquoise')
sns.distplot(random.beta(1,1))
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:ylabel='Density'>

# %%
mu, sigma = 1, 2
s = np.random.normal(mu, sigma, 100)
abs(mu - np.mean(s))
abs(sigma - np.std(s, ddof=1))
count, bins, ignored = plt.hist(s, 30, density=True, color='salmon')
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins - mu)**2 / (2 * sigma**2) ),linewidth=2, color='r')
plt.title("Rozkłd normalny $N(1,2^2)$ dla $n=100$ prób")
plt.savefig('normal12n100')

# %%
np.random.normal(1, 2, size=(2, 4))
# Out:
# array([[ 1.47841014, -0.50188565, -0.53571157,  0.11598888],
#        [-0.8950543 ,  2.42624712,  0.99766563,  2.28694278]])

# %% [markdown]
# Próba rozmiaru $n=100$ dla rozkładu wykładniczego $E(2)$.

# %%
e = random.exponential(scale=2)
sns.distplot(random.exponential(size=100), color='red')
plt.title("Rozkład wykładniczy $E(2)$ dla $n=100$ prób")
plt.ylabel('', fontsize='15')
plt.savefig('exponential2n100')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Próba rozmiaru $n=100$ dla rozkładu beta $B(1,1)$.

# %%
alphas = [1.0]
betas = [1.0]
lines = ['solid']
x = np.linspace(0, 1, 100)
fig, ax = plt.subplots(figsize=(6,4))
for a, b, l in zip(alphas, betas, lines):
    s = stats.beta(a, b)
    plt.plot(x, s.pdf(x), color='red');
plt.xlim(0, 1)
plt.ylim(0, 20)
plt.title("Rozkład beta $B(1,1)$ dla $n=100$ prób")
plt.xlabel('', color='blue')
plt.ylabel('', color='blue')
plt.legend(loc=0)
plt.tight_layout()
plt.hist(random.beta(1,1, size=100), color='salmon')
plt.savefig('beta11n100')
# Out:
# No handles with labels found to put in legend.

# %%
data_beta = beta.rvs(1, 1, size=10000)
ax = sns.distplot(data_beta,kde=True, bins=100, color='skyblue', hist=True)
ax.set(xlabel='Beta(1,1)', ylabel='Frequency')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 0, 'Beta(1,1)'), Text(0, 0.5, 'Frequency')]

# %%
from scipy.stats import beta
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 1)

a, b = 1,1
mean, var, skew, kurt = beta.stats(a, b, moments='mvsk')
x = np.linspace(beta.ppf(0.01, a, b), beta.ppf(0.99, a, b), 100)
ax.plot(x, beta.pdf(x, a, b), 'r-', lw=5, alpha=0.6)
rv = beta(a, b)
ax.plot(x, rv.pdf(x), 'k-', lw=2, label='beta')
vals = beta.ppf([0.001, 0.5, 0.999], a, b)
r = beta.rvs(a, b, size=1000)
ax.hist(r, color='salmon')
ax.legend(loc='best', frameon=True)
sns.distplot(random.beta(a,b), color='red')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:ylabel='Density'>

# %%
from statsmodels.graphics.gofplots import qqplot
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [7, 5]
plt.rc('font', size=9)
from scipy.stats import norm, uniform
import numpy as np
np.random.seed(0)
x = np.random.normal(1,2,100)
#qqplot(x,norm,fit=True,line="s")
pp = sm.ProbPlot(x, fit=True)
qq = pp.qqplot(marker='.', markerfacecolor='green', markeredgecolor='green')
sm.qqline(qq.axes[0], line='45', fmt='-', color='black')
plt.title("Wykres kwantylowy - rozkład normalny $N(1,2^2)$ dla $n=100$ prób")
plt.xlabel('', color='blue')
plt.ylabel('', color='blue')
plt.savefig('quantilnorm')

# %%
from statsmodels.graphics.gofplots import qqplot
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [7, 5]
plt.rc('font', size=9)
from scipy.stats import norm, uniform
import numpy as np
np.random.seed(0)
x = np.random.exponential(2, size=100)
#qqplot(x,norm,fit=True,line="s")
pp = sm.ProbPlot(x, fit=True)
qq = pp.qqplot(marker='.', markerfacecolor='green', markeredgecolor='green')
sm.qqline(qq.axes[0], line='45', fmt='-', color='black')
plt.title("Wykres kwantylowy - rozkład wykładniczy $E(2)$ dla $n=100$ prób")
plt.xlabel('',color='b')
plt.ylabel('',color='b')
plt.savefig('quantilexponential')

# %%
from statsmodels.graphics.gofplots import qqplot
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [7, 5]
plt.rc('font', size=9)
from scipy.stats import norm, uniform
import numpy as np
np.random.seed(0)
x = np.random.beta(1,1,100)
#qqplot(x,norm,fit=True,line="s")
pp = sm.ProbPlot(x, fit=True)
qq = pp.qqplot(marker='.', markerfacecolor='green', markeredgecolor='green')
sm.qqline(qq.axes[0], line='45', fmt='-', color='black')
plt.title("Wykres kwantylowy - rozkład beta $B(1,1)$ dla $n=100$ prób")
plt.xlabel('')
plt.ylabel('')
plt.savefig('quantilbeta')

# %%
x = np.arange(-5, 5, 0.02)
plt.plot(x, norm.pdf(x, 0, 1), label='μ: 0, $σ^2$: 1')
plt.plot(x, norm.pdf(x, 0, 2), label='μ:0, $σ^2: 2^2$ ')
plt.plot(x, norm.pdf(x, 1, 1), label='μ:0, $σ^2$: 1')
plt.plot(x, norm.pdf(x, 1, 3**(3/2)), label='μ:1, $σ^2: 3^3$')
plt.legend()
plt.title("Rozkłady normalne $N(0,1), N(0,2^2), N(1,1), N(1,3^3)$ dla próby $n=200$")
plt.savefig('4normal')

# %%
import scipy.stats as stats
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
plt.style.use('seaborn')
x1 = np.random.normal(0, 1, size=100)
x2 = np.random.normal(0, 2, size=100)
x3 = np.random.normal(1, 1, size=100)
x4 = np.random.normal(1,3**(3/2), size=100)
fig, ax = plt.subplots(1, 1, figsize=(8, 6))
stats.probplot(x1, dist=stats.norm, plot=plt, fit=True)
stats.probplot(x2, dist=stats.norm, plot=plt, fit=True)
stats.probplot(x3, dist=stats.norm,  plot=plt, fit=True)
stats.probplot(x4, dist=stats.norm, plot=plt, fit=True)
custom_lines = [Line2D([0], [0], color='lightblue', lw=4),
                Line2D([0], [0], color='coral', lw=4),
                Line2D([0], [0], color='yellowgreen', lw=4),
               Line2D([0], [0], color='plum', lw=4)]
ax.legend(custom_lines, ['$N(0,1)$', '$N(0,2^2)$', '$N(1,1)$', "$N(1,3^3)$"], loc='best')

ax.get_lines()[1].remove()
ax.get_lines()[2].remove()
ax.get_lines()[3].remove()
# Change colour of scatter
ax.get_lines()[0].set_markerfacecolor('lightblue')
ax.get_lines()[1].set_markerfacecolor('coral')
ax.get_lines()[2].set_markerfacecolor('yellowgreen')
ax.get_lines()[3].set_markerfacecolor('plum')
plt.title("Wykres kwantylowy - rozkłady normalne $N(0,1), N(0,2^2), N(1,1), N(1,3^3)$ dla próby $n=200$")



# Add on y=x line
ax.plot([0, 1], [0, 1], c='C2')
plt.savefig('4normalquantil')

# %%
sns.set(style="darkgrid")
df = np.random.normal(0, 1, size=100)
 
# creating a figure composed of two matplotlib.Axes objects (ax_box and ax_hist)
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})
 
# assigning a graph to each ax
sns.boxplot(df["sepal_length"], ax=ax_box)
sns.histplot(data=df, x="sepal_length", ax=ax_hist)
 
# Remove x axis name for the boxplot
ax_box.set(xlabel='')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-88-aaf9b5627f89> in <module>
#       6
#       7 # assigning a graph to each ax
# ----> 8 sns.boxplot(df["sepal_length"], ax=ax_box)
#       9 sns.histplot(data=df, x="sepal_length", ax=ax_hist)
#      10
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
x = np.arange(-5, 5, 0.02)
plt.plot(x, norm.pdf(x, 0, 1), label='μ: 0, $σ^2$: 1')
plt.plot(x, norm.pdf(x, 0, 2), label='μ:0, $σ^2: 2^2$ ')
plt.plot(x, norm.pdf(x, 1, 1), label='μ:1, $σ^2$: 1')
plt.plot(x, norm.pdf(x, 1, 3**(3/2)), label='μ:1, $σ^2: 3^3$')
plt.legend()
plt.title("Rozkłady normalne $N(0,1), N(0,2^2), N(1,1), N(1,3^3)$ dla próby $n=200$")
plt.savefig('4normal')

# %%
np.random.seed(10)
data_1 = np.random.normal(0, 1, 200)
data_2 = np.random.normal(0, 2, 200)
data_3 = np.random.normal(1, 1, 200)
data_4 = np.random.normal(1, 3**(3/2), 200)
data = [data_1, data_2, data_3, data_4]
 
fig = plt.figure(figsize=(8,6))
 
# Creating axes instance
ax = fig.add_axes([0, 0, 1, 1])
ax.yaxis.grid(True, linestyle='-', which='major', color='lightgrey',alpha=0.5)
# Creating plot
bp = ax.boxplot(data, labels=("$N(0,1)$","$N(0,2^2)$","$N(1,1)$", "$N(1,3^3)$"))
plt.title("Box ploty rozkładów normalnych $N(0,1), N(0,2^2), N(1,1), N(1,3^3)$ dla próby $n=200$") 
# show plot
plt.minorticks_on()
plt.savefig('boxplotnormal')

# %%
normal = np.random.normal(0, 1, size=(200, 1))

# %%
no =pd.DataFrame(normal)
no
# Out:
#             0
# 0    1.102552
# 1    0.410938
# 2    1.199534
# 3    0.478689
# 4    0.784999
# ..        ...
# 195  0.284299
# 196  0.032230
# 197 -1.270315
# 198 -0.366767
# 199 -1.431366
#
# [200 rows x 1 columns]

# %%
qunorm=no.quantile([0.25,0.75])
qunorm #0.25 to kwantyl dolny i 0.75 to kwantyl górny
# Out:
#              0
# 0.25 -0.575439
# 0.75  0.814305

# %%
round(float(no.median(axis = 0)),6) #mediana
# Out:
# 0.034381
